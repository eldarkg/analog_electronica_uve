# %%
# %matplotlib widget

from sympy.abc import U

from visual import disp, plot

# %%
a0 = 5E-4
a1 = 4
Ulim = (U, -2, 2)

# %%
# 1
G = a0 * (a1 - U)
disp(G)
plot(G, Ulim)
# Out:
# $G({U}) = 0.002 - 0.0005 U, См$
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
R = 1 / G
disp(R)
plot(R, Ulim)
# Out:
# $R({U}) = \frac{1}{0.002 - 0.0005 U}, Ом$
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 2
I = U * G
disp(I)
plot(I, Ulim)
# Out:
# $I({U}) = U \left(0.002 - 0.0005 U\right), А$
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
