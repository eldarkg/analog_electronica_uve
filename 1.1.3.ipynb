# %%
# %matplotlib widget

import pandas as pd

import sympy
from sympy.abc import U

from visual import disp, plot
from calculate import op

# %%
C = 120
betta = 0.16
U_A = 100
I = (U / C) ** (1 / betta)
disp(I)
plot(I, (U, 0, U_A + 10))
# Out:
# $I({U}) = 1.01185250736667 \cdot 10^{-13} U^{6.25}, А$
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
g = sympy.diff(I, U)
disp(g)
r = 1 / g
disp(r)
# Out:
# $g({U}) = 6.32407817104171 \cdot 10^{-13} U^{5.25}, См$
# $r({U}) = \frac{1581258126408.14}{U^{5.25}}, Ом$

# %%
r_A = r.subs(U, U_A)
disp(r_A)
# Out:
# $r_A = 50.0037724810016, Ом$

# %%
U_S = (U - I * r).subs(U, U_A)
disp(U_S)
# Out:
# $U_S = 84.0, В$
