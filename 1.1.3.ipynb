# %%
# %matplotlib widget

import pandas as pd

import sympy
from sympy.abc import U, C, beta

from visual import disp, plot

# %%
U_A = 100
I = (U / C) ** (1 / beta)
disp(I)
# Out:
# $I = 1000.0 \left(\frac{U}{C}\right)^{\frac{1}{\beta}}, мА$

# %%
I = I.subs([(C, 120), (beta, 0.16)])
disp(I)
plot(I, (U, 0, U_A + 10))
# Out:
# $I = 1.01185250736667 \cdot 10^{-10} U^{6.25}, мА$
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
g = sympy.diff(I, U)
disp(g)
r = 1 / g
disp(r, si=True)
# Out:
# $g = 6.32407817104171 \cdot 10^{-10} U^{5.25}, мСм$
# $r = \frac{1581258126408.14}{U^{5.25}}, Ом$

# %%
r_A = r.subs(U, U_A)
disp(r_A, si=True)
# Out:
# $r_A = 50.0037724810016, Ом$

# %%
U_S = (U - I * r).subs(U, U_A)
disp(U_S)
# Out:
# $U_S = 84.0, В$
